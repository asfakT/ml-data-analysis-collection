# %%
import pandas as pd
df = pd.read_csv('CSE Thesis - Sheet1.csv')
df.columns = df.iloc[0]  # Set the first row as the header
df = df.drop(index=0)    # Drop the first row
df.reset_index(drop=True, inplace=True)
df
# Out:
# 0                Date                name                        e-mail  \
# 0    2024-04-24 09:30  Israt Jahan Reshma      isratjahan151q@gmail.com
# 1    2024-04-24 09:58             Rafiqur          ripon18922@gmail.com
# 2    2024-04-24 09:58        Alamin Riyad       alaminriyad35@gmail.com
# 3    2024-04-24 10:18    Md Rakibul Islam  mislam221362@bscse.uiu.ac.bd
# 4    2024-04-24 10:18         Nahid Hasan      nahidhasan9613@gmail.com
# ..                ...                 ...                           ...
# 268  2024-08-23 23:27                 NaN                           NaN
# 269  2024-08-23 23:45                 NaN                           NaN
# 270  2024-08-23 23:46                 NaN                           NaN
# 271  2024-08-23 23:47                 NaN                           NaN
# 272  2024-08-23 18:06                 NaN                           NaN
#
# 0    gender year  cgpa                                    university_name  \
# 0    Female  4th  3.84  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 1      Male  4th   2.5  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 2      Male  4th  3.34  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 3      Male  4th  3.78              United International University (UIU)
# 4      Male  4th     3  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# ..      ...  ...   ...                                                ...
# 268    Male  4th     3  Shahjalal University of Science & Technology (...
# 269    Male  4th  3.23  Shahjalal University of Science & Technology (...
# 270  Female  4th  2.98                      University of Chittagong (CU)
# 271    Male  4th  3.78  Shahjalal University of Science & Technology (...
# 272    Male  4th  2.91                      University of Chittagong (CU)
#
# 0   Critical Thinking Problem Solving     Team Work  ...  \
# 0        Intermediate    Intermediate       Advance  ...
# 1               Basic           Basic         Basic  ...
# 2        Intermediate    Intermediate  Intermediate  ...
# 3        Intermediate    Intermediate  Intermediate  ...
# 4        Intermediate    Intermediate       Advance  ...
# ..                ...             ...           ...  ...
# 268           Advance         Advance       Advance  ...
# 269           Advance           Basic  Intermediate  ...
# 270      Intermediate    Intermediate       Advance  ...
# 271           Advance    Intermediate  Intermediate  ...
# 272             Basic           Basic  Intermediate  ...
#
# 0   Understanding Operating System Networking Concept Cyber Security  \
# 0                            Basic                NaN            NaN
# 1                            Basic              Basic          Basic
# 2                            Basic              Basic          Basic
# 3                     Intermediate       Intermediate          Basic
# 4                     Intermediate            Advance        Advance
# ..                             ...                ...            ...
# 268                        Advance              Basic          Basic
# 269                        Advance       Intermediate   Intermediate
# 270                   Intermediate                NaN            NaN
# 271                   Intermediate       Intermediate   Intermediate
# 272                          Basic                NaN            NaN
#
# 0   Maching Learning Robotics Research Skill publication project  \
# 0              Basic      NaN   Intermediate           1       2
# 1              Basic    Basic          Basic         NaN     NaN
# 2              Basic    Basic          Basic           0       2
# 3              Basic    Basic          Basic           0       1
# 4              Basic    Basic          Basic           0       5
# ..               ...      ...            ...         ...     ...
# 268            Basic    Basic          Basic           0       5
# 269          Advance  Advance          Basic           0       4
# 270            Basic      NaN            NaN           1       3
# 271            Basic    Basic        Advance           4       1
# 272              NaN      NaN          Basic           0       2
#
# 0                                   Influencing Factor  \
# 0                                         Job Security
# 1                          flaxible Work Life Balanced
# 2                                      Job Environment
# 3                                         Job Security
# 4                                               Salary
# ..                                                 ...
# 268                                Job Security,Salary
# 269                                Job Security,Salary
# 270                  Social Acceptance,Job Environment
# 271                 Salary,flaxible Work Life Balanced
# 272  Social Acceptance,Job Security,flaxible Work L...
#
# 0                               Prefer Job
# 0                     Software Development
# 1                                 Teaching
# 2                     Software Development
# 3                     Software Development
# 4                     Software Development
# ..                                     ...
# 268        Software Development,Networking
# 269           Data Analysis,ML/AI Engineer
# 270          Software Development,Govt Job
# 271                        Teaching,Abroad
# 272  Bank Job,BCS,Business,Govt Job,Abroad
#
# [273 rows x 27 columns]

# %%
df.shape
# Out:
# (273, 27)

# %%
df.drop(['Date','name','e-mail'], axis=1, inplace=True)
df
# Out:
# 0    gender year  cgpa                                    university_name  \
# 0    Female  4th  3.84  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 1      Male  4th   2.5  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 2      Male  4th  3.34  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 3      Male  4th  3.78              United International University (UIU)
# 4      Male  4th     3  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# ..      ...  ...   ...                                                ...
# 268    Male  4th     3  Shahjalal University of Science & Technology (...
# 269    Male  4th  3.23  Shahjalal University of Science & Technology (...
# 270  Female  4th  2.98                      University of Chittagong (CU)
# 271    Male  4th  3.78  Shahjalal University of Science & Technology (...
# 272    Male  4th  2.91                      University of Chittagong (CU)
#
# 0   Critical Thinking Problem Solving     Team Work Communication Skill  \
# 0        Intermediate    Intermediate       Advance        Intermediate
# 1               Basic           Basic         Basic               Basic
# 2        Intermediate    Intermediate  Intermediate               Basic
# 3        Intermediate    Intermediate  Intermediate        Intermediate
# 4        Intermediate    Intermediate       Advance        Intermediate
# ..                ...             ...           ...                 ...
# 268           Advance         Advance       Advance        Intermediate
# 269           Advance           Basic  Intermediate               Basic
# 270      Intermediate    Intermediate       Advance        Intermediate
# 271           Advance    Intermediate  Intermediate             Advance
# 272             Basic           Basic  Intermediate             Advance
#
# 0   Software Engineering Principal Data Structure & Algorithm  ...  \
# 0                     Intermediate                    Advance  ...
# 1                            Basic                      Basic  ...
# 2                            Basic               Intermediate  ...
# 3                            Basic               Intermediate  ...
# 4                     Intermediate               Intermediate  ...
# ..                             ...                        ...  ...
# 268                        advance                    Advance  ...
# 269                   Intermediate                    Advance  ...
# 270                          Basic               Intermediate  ...
# 271                          Basic               Intermediate  ...
# 272                          Basic                      Basic  ...
#
# 0   Understanding Operating System Networking Concept Cyber Security  \
# 0                            Basic                NaN            NaN
# 1                            Basic              Basic          Basic
# 2                            Basic              Basic          Basic
# 3                     Intermediate       Intermediate          Basic
# 4                     Intermediate            Advance        Advance
# ..                             ...                ...            ...
# 268                        Advance              Basic          Basic
# 269                        Advance       Intermediate   Intermediate
# 270                   Intermediate                NaN            NaN
# 271                   Intermediate       Intermediate   Intermediate
# 272                          Basic                NaN            NaN
#
# 0   Maching Learning Robotics Research Skill publication project  \
# 0              Basic      NaN   Intermediate           1       2
# 1              Basic    Basic          Basic         NaN     NaN
# 2              Basic    Basic          Basic           0       2
# 3              Basic    Basic          Basic           0       1
# 4              Basic    Basic          Basic           0       5
# ..               ...      ...            ...         ...     ...
# 268            Basic    Basic          Basic           0       5
# 269          Advance  Advance          Basic           0       4
# 270            Basic      NaN            NaN           1       3
# 271            Basic    Basic        Advance           4       1
# 272              NaN      NaN          Basic           0       2
#
# 0                                   Influencing Factor  \
# 0                                         Job Security
# 1                          flaxible Work Life Balanced
# 2                                      Job Environment
# 3                                         Job Security
# 4                                               Salary
# ..                                                 ...
# 268                                Job Security,Salary
# 269                                Job Security,Salary
# 270                  Social Acceptance,Job Environment
# 271                 Salary,flaxible Work Life Balanced
# 272  Social Acceptance,Job Security,flaxible Work L...
#
# 0                               Prefer Job
# 0                     Software Development
# 1                                 Teaching
# 2                     Software Development
# 3                     Software Development
# 4                     Software Development
# ..                                     ...
# 268        Software Development,Networking
# 269           Data Analysis,ML/AI Engineer
# 270          Software Development,Govt Job
# 271                        Teaching,Abroad
# 272  Bank Job,BCS,Business,Govt Job,Abroad
#
# [273 rows x 24 columns]

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
university = df.groupby('university_name').size().reset_index(name='Count')
university = university.sort_values(by='Count',ascending=False)
print(university)
# Out:
#                                       university_name  Count
# 1   Bangabandhu Sheikh Mujibur Rahman Science & Te...     68
# 0   American International University-Bangladesh (...     26
# 4                            Comilla University (CoU)     25
# 23              United International University (UIU)     21
# 8   Hajee Mohammad Danesh Science & Technology Uni...     18
# 24                      University of Chittagong (CU)     12
# 26                        University of Rajshahi (RU)     11
# 13                      Jahangirnagar University (JU)     10
# 22  Shahjalal University of Science & Technology (...     10
# 9            Independent University, Bangladesh (IUB)      9
# 21  Rajshahi University of Engineering & Technolog...      8
# 15  Mawlana Bhashani Science & Technology Universi...      7
# 5             Daffodil International University (DIU)      7
# 19  Patuakhali  Science and technology university ...      7
# 25                           University of Dhaka (DU)      6
# 7                        Faridpur Engineering College      4
# 14                             Khulna University (KU)      4
# 12                Islamic University, Bangladesh (IU)      4
# 18               Northern University Bangladesh (NUB)      3
# 20          Port City International University (PCIU)      2
# 11  International University of Business Agricultu...      2
# 3   Bangladesh University of Engineering & Technol...      2
# 2   Bangabandhu Sheikh Mujibur Rahman Science & Te...      2
# 10  International Islamic University Chittagong (I...      2
# 16                    Mymensingh Engineering College       1
# 6                          East West University (EWU)      1
# 17    Noakhali Science & Technology University (NSTU)      1

# %%
university.shape
# Out:
# (27, 2)

# %%
year = df.groupby('year').size().reset_index(name='Count')
year = year.sort_values(by='Count',ascending=False)
year
# Out:
#   year  Count
# 3  4th    183
# 2  3rd     47
# 1  2nd     29
# 0  1st     14

# %%
year.sum()
# Out:
# year     4th3rd2nd1st
# Count             273
# dtype: object

# %%
df.isna().sum()
# Out:
# 0
# gender                                              0
# year                                                0
# cgpa                                                8
# university_name                                     0
# Critical Thinking                                   5
# Problem Solving                                     4
# Team Work                                           4
# Communication Skill                                 5
# Software Engineering Principal                     14
# Data Structure & Algorithm                          8
# Database Management                                10
# Data Analysis                                      14
# Web Developing Skill                               18
# Understanding of computer architecture & System    19
# Understanding Operating System                     18
# Networking Concept                                 24
# Cyber Security                                     25
# Maching Learning                                   28
# Robotics                                           42
# Research Skill                                     31
# publication                                        41
# project                                            18
# Influencing Factor                                 15
# Prefer Job                                          9
# dtype: int64

# %%
df['year']=df['year'].fillna('4th')
df
# Out:
# 0    gender year  cgpa                                    university_name  \
# 0    Female  4th  3.84  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 1      Male  4th   2.5  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 2      Male  4th  3.34  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 3      Male  4th  3.78              United International University (UIU)
# 4      Male  4th     3  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# ..      ...  ...   ...                                                ...
# 268    Male  4th     3  Shahjalal University of Science & Technology (...
# 269    Male  4th  3.23  Shahjalal University of Science & Technology (...
# 270  Female  4th  2.98                      University of Chittagong (CU)
# 271    Male  4th  3.78  Shahjalal University of Science & Technology (...
# 272    Male  4th  2.91                      University of Chittagong (CU)
#
# 0   Critical Thinking Problem Solving     Team Work Communication Skill  \
# 0        Intermediate    Intermediate       Advance        Intermediate
# 1               Basic           Basic         Basic               Basic
# 2        Intermediate    Intermediate  Intermediate               Basic
# 3        Intermediate    Intermediate  Intermediate        Intermediate
# 4        Intermediate    Intermediate       Advance        Intermediate
# ..                ...             ...           ...                 ...
# 268           Advance         Advance       Advance        Intermediate
# 269           Advance           Basic  Intermediate               Basic
# 270      Intermediate    Intermediate       Advance        Intermediate
# 271           Advance    Intermediate  Intermediate             Advance
# 272             Basic           Basic  Intermediate             Advance
#
# 0   Software Engineering Principal Data Structure & Algorithm  ...  \
# 0                     Intermediate                    Advance  ...
# 1                            Basic                      Basic  ...
# 2                            Basic               Intermediate  ...
# 3                            Basic               Intermediate  ...
# 4                     Intermediate               Intermediate  ...
# ..                             ...                        ...  ...
# 268                        advance                    Advance  ...
# 269                   Intermediate                    Advance  ...
# 270                          Basic               Intermediate  ...
# 271                          Basic               Intermediate  ...
# 272                          Basic                      Basic  ...
#
# 0   Understanding Operating System Networking Concept Cyber Security  \
# 0                            Basic                NaN            NaN
# 1                            Basic              Basic          Basic
# 2                            Basic              Basic          Basic
# 3                     Intermediate       Intermediate          Basic
# 4                     Intermediate            Advance        Advance
# ..                             ...                ...            ...
# 268                        Advance              Basic          Basic
# 269                        Advance       Intermediate   Intermediate
# 270                   Intermediate                NaN            NaN
# 271                   Intermediate       Intermediate   Intermediate
# 272                          Basic                NaN            NaN
#
# 0   Maching Learning Robotics Research Skill publication project  \
# 0              Basic      NaN   Intermediate           1       2
# 1              Basic    Basic          Basic         NaN     NaN
# 2              Basic    Basic          Basic           0       2
# 3              Basic    Basic          Basic           0       1
# 4              Basic    Basic          Basic           0       5
# ..               ...      ...            ...         ...     ...
# 268            Basic    Basic          Basic           0       5
# 269          Advance  Advance          Basic           0       4
# 270            Basic      NaN            NaN           1       3
# 271            Basic    Basic        Advance           4       1
# 272              NaN      NaN          Basic           0       2
#
# 0                                   Influencing Factor  \
# 0                                         Job Security
# 1                          flaxible Work Life Balanced
# 2                                      Job Environment
# 3                                         Job Security
# 4                                               Salary
# ..                                                 ...
# 268                                Job Security,Salary
# 269                                Job Security,Salary
# 270                  Social Acceptance,Job Environment
# 271                 Salary,flaxible Work Life Balanced
# 272  Social Acceptance,Job Security,flaxible Work L...
#
# 0                               Prefer Job
# 0                     Software Development
# 1                                 Teaching
# 2                     Software Development
# 3                     Software Development
# 4                     Software Development
# ..                                     ...
# 268        Software Development,Networking
# 269           Data Analysis,ML/AI Engineer
# 270          Software Development,Govt Job
# 271                        Teaching,Abroad
# 272  Bank Job,BCS,Business,Govt Job,Abroad
#
# [273 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 24 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   gender                                           273 non-null    object
#  1   year                                             273 non-null    object
#  2   cgpa                                             265 non-null    object
#  3   university_name                                  273 non-null    object
#  4   Critical Thinking                                268 non-null    object
#  5   Problem Solving                                  269 non-null    object
#  6   Team Work                                        269 non-null    object
#  7   Communication Skill                              268 non-null    object
#  8   Software Engineering Principal                   259 non-null    object
#  9   Data Structure & Algorithm                       265 non-null    object
#  10  Database Management                              263 non-null    object
#  11  Data Analysis                                    259 non-null    object
#  12  Web Developing Skill                             255 non-null    object
#  13  Understanding of computer architecture & System  254 non-null    object
#  14  Understanding Operating System                   255 non-null    object
#  15  Networking Concept                               249 non-null    object
#  16  Cyber Security                                   248 non-null    object
#  17  Maching Learning                                 245 non-null    object
#  18  Robotics                                         231 non-null    object
#  19  Research Skill                                   242 non-null    object
#  20  publication                                      232 non-null    object
#  21  project                                          255 non-null    object
#  22  Influencing Factor                               258 non-null    object
#  23  Prefer Job                                       264 non-null    object
# dtypes: object(24)
# memory usage: 51.3+ KB

# %%
df['publication']=df['publication'].fillna(0)
df['project']=df['project'].fillna(0)
print(df['publication'])
print(df['project'])
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 268    0
# 269    0
# 270    1
# 271    4
# 272    0
# Name: publication, Length: 273, dtype: object
# 0      2
# 1      0
# 2      2
# 3      1
# 4      5
#       ..
# 268    5
# 269    4
# 270    3
# 271    1
# 272    2
# Name: project, Length: 273, dtype: object

# %%
#converted publication and research_paper int int32 form
convert_dict = {'publication': 'int16',
                'project': 'int16',
                'cgpa':'float64'
               }
df = df.astype(convert_dict)
df.sample(10)
# Out:
# 0    gender year  cgpa                                    university_name  \
# 33   Female  1st  3.61            Daffodil International University (DIU)
# 88     Male  1st  3.16               Northern University Bangladesh (NUB)
# 160    Male  4th  2.95  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 119    Male  4th  3.00  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 100  Female  2nd  2.93  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 65   Female  2nd  3.50                           Comilla University (CoU)
# 106    Male  4th  3.30  Mawlana Bhashani Science & Technology Universi...
# 56     Male  4th  3.33                       Faridpur Engineering College
# 62   Female  1st  3.60                           Comilla University (CoU)
# 87     Male  4th  3.63  Bangabandhu Sheikh Mujibur Rahman Science & Te...
#
# 0   Critical Thinking Problem Solving     Team Work Communication Skill  \
# 33              Basic           Basic  Intermediate               Basic
# 88              Basic    Intermediate         Basic        Intermediate
# 160      Intermediate    Intermediate  Intermediate               Basic
# 119             Basic           Basic         Basic               Basic
# 100             Basic           Basic         Basic               Basic
# 65              Basic           Basic         Basic               Basic
# 106             Basic           Basic       Advance             Advance
# 56       Intermediate    Intermediate  Intermediate               Basic
# 62              Basic           Basic  Intermediate        Intermediate
# 87              Basic    Intermediate       Advance        Intermediate
#
# 0   Software Engineering Principal Data Structure & Algorithm  ...  \
# 33                             NaN                        NaN  ...
# 88                           Basic                      Basic  ...
# 160                          Basic                      Basic  ...
# 119                          Basic                      Basic  ...
# 100                          Basic                      Basic  ...
# 65                           Basic                      Basic  ...
# 106                   Intermediate               Intermediate  ...
# 56                    Intermediate               Intermediate  ...
# 62                           Basic               Intermediate  ...
# 87                    Intermediate               Intermediate  ...
#
# 0   Understanding Operating System Networking Concept Cyber Security  \
# 33                             NaN                NaN            NaN
# 88                    Intermediate              Basic   Intermediate
# 160                          Basic              Basic          Basic
# 119                          Basic              Basic          Basic
# 100                          Basic              Basic          Basic
# 65                           Basic              Basic          Basic
# 106                        Advance            Advance   Intermediate
# 56                           Basic       Intermediate   Intermediate
# 62                    Intermediate              Basic   Intermediate
# 87                    Intermediate       Intermediate   Intermediate
#
# 0   Maching Learning      Robotics Research Skill publication project  \
# 33               NaN           NaN            NaN           0       0
# 88      Intermediate         Basic          Basic           2       2
# 160            Basic         Basic          Basic           0       4
# 119            Basic         Basic          Basic           0       3
# 100            Basic         Basic          Basic           0       1
# 65             Basic         Basic          Basic           0       0
# 106            Basic         Basic   Intermediate           0       4
# 56      Intermediate  Intermediate   Intermediate           1       2
# 62             Basic         Basic          Basic           0       0
# 87             Basic         Basic          Basic           0      10
#
# 0                                   Influencing Factor  \
# 33                                                 NaN
# 88      Social Acceptance,Job Security,Job Environment
# 160                                Job Security,Salary
# 119                                    Job Environment
# 100                        flaxible Work Life Balanced
# 65                                              Salary
# 106  Social Acceptance,Job Security,Job Environment...
# 56                                                 NaN
# 62                                              Salary
# 87   Social Acceptance,Job Security,flaxible Work L...
#
# 0                               Prefer Job
# 33                                   Other
# 88               Networking,Cyber Security
# 160            Software Development,Abroad
# 119  Database Administration,Data Analysis
# 100                                  Other
# 65                                Business
# 106          Software Development,Bank Job
# 56      Software Development,Data Analysis
# 62                                Business
# 87                    Software Development
#
# [10 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 24 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   gender                                           273 non-null    object
#  1   year                                             273 non-null    object
#  2   cgpa                                             265 non-null    float64
#  3   university_name                                  273 non-null    object
#  4   Critical Thinking                                268 non-null    object
#  5   Problem Solving                                  269 non-null    object
#  6   Team Work                                        269 non-null    object
#  7   Communication Skill                              268 non-null    object
#  8   Software Engineering Principal                   259 non-null    object
#  9   Data Structure & Algorithm                       265 non-null    object
#  10  Database Management                              263 non-null    object
#  11  Data Analysis                                    259 non-null    object
#  12  Web Developing Skill                             255 non-null    object
#  13  Understanding of computer architecture & System  254 non-null    object
#  14  Understanding Operating System                   255 non-null    object
#  15  Networking Concept                               249 non-null    object
#  16  Cyber Security                                   248 non-null    object
#  17  Maching Learning                                 245 non-null    object
#  18  Robotics                                         231 non-null    object
#  19  Research Skill                                   242 non-null    object
#  20  publication                                      273 non-null    int16
#  21  project                                          273 non-null    int16
#  22  Influencing Factor                               258 non-null    object
#  23  Prefer Job                                       264 non-null    object
# dtypes: float64(1), int16(2), object(21)
# memory usage: 48.1+ KB

# %%
project = df.groupby('project').size().reset_index(name='Count')
#year = year.sort_values(by='Count',ascending=False)
project
# Out:
#     project  Count
# 0         0     40
# 1         1     50
# 2         2     59
# 3         3     33
# 4         4     35
# 5         5     31
# 6         6      5
# 7         7      2
# 8         8      1
# 9         9      2
# 10       10      6
# 11       11      2
# 12       15      1
# 13       25      2
# 14       30      1
# 15       50      1
# 16       65      1
# 17      100      1

# %%
publication = df.groupby('publication').size().reset_index(name='Count')
#year = year.sort_values(by='Count',ascending=False)
publication
# Out:
#    publication  Count
# 0            0    211
# 1            1     33
# 2            2     17
# 3            3      4
# 4            4      2
# 5            5      3
# 6            7      1
# 7           30      2

# %%
df.describe()
# Out:
# 0            cgpa  publication     project
# count  265.000000   273.000000  273.000000
# mean     3.274075     0.619048    3.750916
# std      0.522630     2.703743    8.252242
# min      0.000000     0.000000    0.000000
# 25%      3.010000     0.000000    1.000000
# 50%      3.320000     0.000000    2.000000
# 75%      3.590000     0.000000    4.000000
# max      4.000000    30.000000  100.000000

# %%
df.isna().sum()
# Out:
# 0
# gender                                              0
# year                                                0
# cgpa                                                8
# university_name                                     0
# Critical Thinking                                   5
# Problem Solving                                     4
# Team Work                                           4
# Communication Skill                                 5
# Software Engineering Principal                     14
# Data Structure & Algorithm                          8
# Database Management                                10
# Data Analysis                                      14
# Web Developing Skill                               18
# Understanding of computer architecture & System    19
# Understanding Operating System                     18
# Networking Concept                                 24
# Cyber Security                                     25
# Maching Learning                                   28
# Robotics                                           42
# Research Skill                                     31
# publication                                         0
# project                                             0
# Influencing Factor                                 15
# Prefer Job                                          9
# dtype: int64

# %%
df['cgpa'].isna().sum()
# Out:
# 8

# %%
df['cgpa'].mean()
# Out:
# 3.2740754716981133

# %%
df['cgpa']=df['cgpa'].fillna(df['cgpa'].mean())

# %%
df
# Out:
# 0    gender year  cgpa                                    university_name  \
# 0    Female  4th  3.84  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 1      Male  4th  2.50  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 2      Male  4th  3.34  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 3      Male  4th  3.78              United International University (UIU)
# 4      Male  4th  3.00  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# ..      ...  ...   ...                                                ...
# 268    Male  4th  3.00  Shahjalal University of Science & Technology (...
# 269    Male  4th  3.23  Shahjalal University of Science & Technology (...
# 270  Female  4th  2.98                      University of Chittagong (CU)
# 271    Male  4th  3.78  Shahjalal University of Science & Technology (...
# 272    Male  4th  2.91                      University of Chittagong (CU)
#
# 0   Critical Thinking Problem Solving     Team Work Communication Skill  \
# 0        Intermediate    Intermediate       Advance        Intermediate
# 1               Basic           Basic         Basic               Basic
# 2        Intermediate    Intermediate  Intermediate               Basic
# 3        Intermediate    Intermediate  Intermediate        Intermediate
# 4        Intermediate    Intermediate       Advance        Intermediate
# ..                ...             ...           ...                 ...
# 268           Advance         Advance       Advance        Intermediate
# 269           Advance           Basic  Intermediate               Basic
# 270      Intermediate    Intermediate       Advance        Intermediate
# 271           Advance    Intermediate  Intermediate             Advance
# 272             Basic           Basic  Intermediate             Advance
#
# 0   Software Engineering Principal Data Structure & Algorithm  ...  \
# 0                     Intermediate                    Advance  ...
# 1                            Basic                      Basic  ...
# 2                            Basic               Intermediate  ...
# 3                            Basic               Intermediate  ...
# 4                     Intermediate               Intermediate  ...
# ..                             ...                        ...  ...
# 268                        advance                    Advance  ...
# 269                   Intermediate                    Advance  ...
# 270                          Basic               Intermediate  ...
# 271                          Basic               Intermediate  ...
# 272                          Basic                      Basic  ...
#
# 0   Understanding Operating System Networking Concept Cyber Security  \
# 0                            Basic                NaN            NaN
# 1                            Basic              Basic          Basic
# 2                            Basic              Basic          Basic
# 3                     Intermediate       Intermediate          Basic
# 4                     Intermediate            Advance        Advance
# ..                             ...                ...            ...
# 268                        Advance              Basic          Basic
# 269                        Advance       Intermediate   Intermediate
# 270                   Intermediate                NaN            NaN
# 271                   Intermediate       Intermediate   Intermediate
# 272                          Basic                NaN            NaN
#
# 0   Maching Learning Robotics Research Skill publication project  \
# 0              Basic      NaN   Intermediate           1       2
# 1              Basic    Basic          Basic           0       0
# 2              Basic    Basic          Basic           0       2
# 3              Basic    Basic          Basic           0       1
# 4              Basic    Basic          Basic           0       5
# ..               ...      ...            ...         ...     ...
# 268            Basic    Basic          Basic           0       5
# 269          Advance  Advance          Basic           0       4
# 270            Basic      NaN            NaN           1       3
# 271            Basic    Basic        Advance           4       1
# 272              NaN      NaN          Basic           0       2
#
# 0                                   Influencing Factor  \
# 0                                         Job Security
# 1                          flaxible Work Life Balanced
# 2                                      Job Environment
# 3                                         Job Security
# 4                                               Salary
# ..                                                 ...
# 268                                Job Security,Salary
# 269                                Job Security,Salary
# 270                  Social Acceptance,Job Environment
# 271                 Salary,flaxible Work Life Balanced
# 272  Social Acceptance,Job Security,flaxible Work L...
#
# 0                               Prefer Job
# 0                     Software Development
# 1                                 Teaching
# 2                     Software Development
# 3                     Software Development
# 4                     Software Development
# ..                                     ...
# 268        Software Development,Networking
# 269           Data Analysis,ML/AI Engineer
# 270          Software Development,Govt Job
# 271                        Teaching,Abroad
# 272  Bank Job,BCS,Business,Govt Job,Abroad
#
# [273 rows x 24 columns]

# %%
df['Prefer Job'].isna().sum()
# Out:
# 9

# %%
df['Prefer Job']=df['Prefer Job'].fillna('other')
df['Influencing Factor']=df['Influencing Factor'].fillna('other')

# %%
df.isna().sum()
# Out:
# 0
# gender                                              0
# year                                                0
# cgpa                                                0
# university_name                                     0
# Critical Thinking                                   5
# Problem Solving                                     4
# Team Work                                           4
# Communication Skill                                 5
# Software Engineering Principal                     14
# Data Structure & Algorithm                          8
# Database Management                                10
# Data Analysis                                      14
# Web Developing Skill                               18
# Understanding of computer architecture & System    19
# Understanding Operating System                     18
# Networking Concept                                 24
# Cyber Security                                     25
# Maching Learning                                   28
# Robotics                                           42
# Research Skill                                     31
# publication                                         0
# project                                             0
# Influencing Factor                                  0
# Prefer Job                                          0
# dtype: int64

# %%
df=df.fillna(0)

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df=df.replace({'Basic','basic'}, 1)
df=df.replace({'Intermediate','intermediate'},2)
df=df.replace({'Advance','advance'},3)
df
# Out:
# 0    gender year  cgpa                                    university_name  \
# 0    Female  4th  3.84  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 1      Male  4th  2.50  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 2      Male  4th  3.34  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 3      Male  4th  3.78              United International University (UIU)
# 4      Male  4th  3.00  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# ..      ...  ...   ...                                                ...
# 268    Male  4th  3.00  Shahjalal University of Science & Technology (...
# 269    Male  4th  3.23  Shahjalal University of Science & Technology (...
# 270  Female  4th  2.98                      University of Chittagong (CU)
# 271    Male  4th  3.78  Shahjalal University of Science & Technology (...
# 272    Male  4th  2.91                      University of Chittagong (CU)
#
# 0    Critical Thinking  Problem Solving  Team Work  Communication Skill  \
# 0                    2                2          3                    2
# 1                    1                1          1                    1
# 2                    2                2          2                    1
# 3                    2                2          2                    2
# 4                    2                2          3                    2
# ..                 ...              ...        ...                  ...
# 268                  3                3          3                    2
# 269                  3                1          2                    1
# 270                  2                2          3                    2
# 271                  3                2          2                    3
# 272                  1                1          2                    3
#
# 0    Software Engineering Principal  Data Structure & Algorithm  ...  \
# 0                                 2                           3  ...
# 1                                 1                           1  ...
# 2                                 1                           2  ...
# 3                                 1                           2  ...
# 4                                 2                           2  ...
# ..                              ...                         ...  ...
# 268                               3                           3  ...
# 269                               2                           3  ...
# 270                               1                           2  ...
# 271                               1                           2  ...
# 272                               1                           1  ...
#
# 0    Understanding Operating System  Networking Concept  Cyber Security  \
# 0                                 1                   0               0
# 1                                 1                   1               1
# 2                                 1                   1               1
# 3                                 2                   2               1
# 4                                 2                   3               3
# ..                              ...                 ...             ...
# 268                               3                   1               1
# 269                               3                   2               2
# 270                               2                   0               0
# 271                               2                   2               2
# 272                               1                   0               0
#
# 0    Maching Learning  Robotics  Research Skill  publication  project  \
# 0                   1         0               2            1        2
# 1                   1         1               1            0        0
# 2                   1         1               1            0        2
# 3                   1         1               1            0        1
# 4                   1         1               1            0        5
# ..                ...       ...             ...          ...      ...
# 268                 1         1               1            0        5
# 269                 3         3               1            0        4
# 270                 1         0               0            1        3
# 271                 1         1               3            4        1
# 272                 0         0               1            0        2
#
# 0                                   Influencing Factor  \
# 0                                         Job Security
# 1                          flaxible Work Life Balanced
# 2                                      Job Environment
# 3                                         Job Security
# 4                                               Salary
# ..                                                 ...
# 268                                Job Security,Salary
# 269                                Job Security,Salary
# 270                  Social Acceptance,Job Environment
# 271                 Salary,flaxible Work Life Balanced
# 272  Social Acceptance,Job Security,flaxible Work L...
#
# 0                               Prefer Job
# 0                     Software Development
# 1                                 Teaching
# 2                     Software Development
# 3                     Software Development
# 4                     Software Development
# ..                                     ...
# 268        Software Development,Networking
# 269           Data Analysis,ML/AI Engineer
# 270          Software Development,Govt Job
# 271                        Teaching,Abroad
# 272  Bank Job,BCS,Business,Govt Job,Abroad
#
# [273 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 24 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   gender                                           273 non-null    object
#  1   year                                             273 non-null    object
#  2   cgpa                                             273 non-null    float64
#  3   university_name                                  273 non-null    object
#  4   Critical Thinking                                273 non-null    int64
#  5   Problem Solving                                  273 non-null    int64
#  6   Team Work                                        273 non-null    int64
#  7   Communication Skill                              273 non-null    int64
#  8   Software Engineering Principal                   273 non-null    int64
#  9   Data Structure & Algorithm                       273 non-null    int64
#  10  Database Management                              273 non-null    int64
#  11  Data Analysis                                    273 non-null    int64
#  12  Web Developing Skill                             273 non-null    int64
#  13  Understanding of computer architecture & System  273 non-null    int64
#  14  Understanding Operating System                   273 non-null    int64
#  15  Networking Concept                               273 non-null    int64
#  16  Cyber Security                                   273 non-null    int64
#  17  Maching Learning                                 273 non-null    int64
#  18  Robotics                                         273 non-null    int64
#  19  Research Skill                                   273 non-null    int64
#  20  publication                                      273 non-null    int16
#  21  project                                          273 non-null    int16
#  22  Influencing Factor                               273 non-null    object
#  23  Prefer Job                                       273 non-null    object
# dtypes: float64(1), int16(2), int64(16), object(5)
# memory usage: 48.1+ KB

# %%
df = df.rename(columns={
    'Data Analysis': 'Data Analysis skill',
    'Cyber Security': 'Cyber Security Skill',
    'Maching Learning':'Machine Learning Skill',
    'Robotics':'Robotics Skill'
})

# %%
df.to_csv('clean_data.csv')

# %%
#from pandas_profiling import ProfileReport
from ydata_profiling import ProfileReport
# Assuming 'df' is your DataFrame
prof = ProfileReport(df)
prof.to_file(output_file='summary.html')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
